# %% [markdown]
#  It has three columns called timestamp , average_sales  and offer_price . We want the library to read this sheet and plot a chart for average_sales  (y-axis)vs. timestamp (x-axis) and save it as an image file on the local disk.

# %%
# importing the library for task 
import plot_chart

# key from my google sheet
key = '1SrZfvr2ee54r7HR1jGtAE9zHIj_Y-UzK9ok8bdwkpqc'

# ploting chart with x and y cordinaters
plot_chart.plot_chart('timestamp','average_sales',key)
